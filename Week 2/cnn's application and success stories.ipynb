# %% [markdown]
# # CNN's: Applications and Success Stories

# %% [markdown]
# ### ImageNet: A large scale visual database
#
# - Hand annotated (via crowdsurfing) knowledge ontology *with > 14 million images, > 20000 categories*.
# - **ImageNet challenge**: Correctly classify and detect objects and scenes.
# - Spurred lots of research in Computer vision in the last decade.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CNN success stories: Object Classification
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CNN success stories: Scene Segmentation & Image Description
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CNN success stories: Healthcare
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What kind of features do different CNN Layers learn?: An Interactive 3D Demo
#
# - In general, **lower layer of deep CNN's learn generic features** and **higher layers learn more specific features for that object class**.
#
# https://www.cs.ryerson.ca/~aharley/vis/conv/
#
# ![image.png](attachment:image.png)
