# %% [markdown]
# # GAN Applications

# %% [markdown]
# ### Generated Samples from GAN's
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CycleGAN: Domain Transformation
#
# Learn transformation between two images based on a GAN-style adversarial loss.
#
# The model can be used to transform input images into certain "styles".
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Style-based Tranfer using GAN's
#
# - Style-based generation by (karras et al. 2018)
# - Proposes a new generator architecture for image synthesis.
# - The website linked below **generates images of people who do not exist.** (Based on a follow-up work by the same authors.)
#
# ![image.png](attachment:image.png)
#
# Link: https://www.thispersondoesnotexist.com

# %% [markdown]
# ### Explosion in "GAN" research
#
# The ever-growing collection of GAN-related papers is indexed at the git repository below:
#
# ![image.png](attachment:image.png)
#
# https://github.com/hindupuravinash/the-gan-zoo
